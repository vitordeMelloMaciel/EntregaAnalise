# %%
# ===================== Análise Exploratória - Banco do Primeiro =====================
# Este notebook conecta ao banco do primeiro (que ainda existe) e gera EDA organizado para cada tabela.

# --------------------- Importações ---------------------
import psycopg2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Configurações de visualização
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (8,5)

# --------------------- URL do banco direto ---------------------
DATABASE_URL = "postgresql://neondb_owner:npg_StuVDjnZ8L3v@ep-still-cake-ad03wttb.c-2.us-east-1.aws.neon.tech/frotaviva?sslmode=require&channel_binding=require"

# --------------------- Conexão com o banco ---------------------
conn = psycopg2.connect(DATABASE_URL, sslmode="require")

# --------------------- Obtém todas as tabelas ---------------------
query_tables = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public'
AND table_type = 'BASE TABLE';
"""

tables = pd.read_sql(query_tables, conn)['table_name'].tolist()
print("Tabelas encontradas:", tables)

# --------------------- Função para EDA ---------------------
def eda_tabela(tabela, conn, limite_linhas=5000):
    print(f"\n\n===== TABELA: {tabela} =====")
    
    # Lê a tabela com limite de linhas (evita travamentos)
    df = pd.read_sql(f"SELECT * FROM {tabela} LIMIT {limite_linhas};", conn)
    
    # Verifica se está vazia
    if df.empty:
        print(" Tabela vazia, pulando...")
        return None

    # --------------------- Ignora colunas inúteis ---------------------
    colunas_inuteis = [
        'id', 'id_', 'idcliente', 'id_cliente', 'id_motorista', 'id_caminhao',
        'cliente_id', 'pedido_id', 'codigo', 'codigo_produto', 'codigo_empresa',
        'telefone', 'email', 'cpf', 'cnpj', 'descricao', 'observacao',
        'comentario', 'created_at', 'updated_at', 'data_criacao', 'data_atualizacao'
    ]
    removidas = [c for c in df.columns if c.lower() in colunas_inuteis]
    df = df.drop(columns=removidas, errors='ignore')

    # Remove colunas sem variação
    df = df.loc[:, df.nunique() > 1]

    if removidas:
        print(f"🔹 Colunas ignoradas: {removidas}")

    # Se a tabela ficar sem colunas, pula a análise
    if df.shape[1] == 0:
        print(" Nenhuma coluna relevante restante após remoção de colunas inúteis. Pulando análise.\n")
        return None
    # ------------------------------------------------------------------------------

    # Informações gerais
    print("\n--- Informações gerais ---")
    print(df.info())
    
    # Estatísticas numéricas
    print("\n--- Estatísticas numéricas ---")
    print(df.describe())
    
    # Estatísticas categóricas (só se houver colunas object)
    cat_cols = df.select_dtypes(include=['object']).columns
    print("\n--- Estatísticas categóricas ---")
    if len(cat_cols) > 0:
        print(df[cat_cols].describe())
    else:
        print("Nenhuma coluna categórica encontrada.")
    
    # Valores ausentes
    print("\n--- Valores ausentes ---")
    print(df.isnull().sum())
    
    # --------------------- Gráficos ---------------------
    num_cols = df.select_dtypes(include=['int64', 'float64']).columns
    
    # Distribuição numérica
    for col in num_cols:
        plt.figure()
        sns.histplot(df[col], kde=True, bins=20)
        plt.title(f'Distribuição de {col} ({tabela})')
        plt.show()
    
    # Contagem de categorias (só se tiver poucas categorias)
    for col in cat_cols:
        if df[col].nunique() < 30:
            plt.figure()
            sns.countplot(y=col, data=df)
            plt.title(f'Contagem de categorias em {col} ({tabela})')
            plt.show()
    
    # Matriz de correlação
    if len(num_cols) > 1:
        plt.figure(figsize=(10,8))
        sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm')
        plt.title(f'Matriz de correlação ({tabela})')
        plt.show()
    
    # Exporta para CSV (opcional)
    df.to_csv(f"{tabela}_EDA.csv", index=False)
    
    return df

# --------------------- Executa EDA para todas as tabelas ---------------------
dfs = {}
for tabela in tables:
    print(f"\n➡️ Analisando tabela: {tabela}")
    dfs[tabela] = eda_tabela(tabela, conn)

# --------------------- Fecha a conexão ---------------------
conn.close()

print("\n✅ Análise concluída! Todos os DataFrames estão salvos no dicionário 'dfs' e exportados como CSV.")
# Out:
# C:\Users\vitormaciel-ieg\AppData\Local\Temp\ipykernel_20080\3303702582.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tables = pd.read_sql(query_tables, conn)['table_name'].tolist()
# Tabelas encontradas: ['empresa', 'motorista', 'telefone_empresa', 'telefone_motorista', 'frota', 'entrega', 'caminhao', 'manutencao', 'informacoes', 'caminhao_motorista']
#
# ➡️ Analisando tabela: empresa
#
#
# ===== TABELA: empresa =====
# 🔹 Colunas ignoradas: ['id', 'cnpj', 'email']
#
# --- Informações gerais ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tipo_empresa  10 non-null     object
#  1   senha         10 non-null     object
#  2   nome          10 non-null     object
# ...
